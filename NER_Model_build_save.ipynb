# %%
import spacy
from spacy.tokens import Doc
from spacy.training import Example
from spacy.util import minibatch, compounding
from spacy.matcher import Matcher
import random
import json
import re

# Step 1: Load the original model
nlp = spacy.load("en_core_web_sm")
nlp.disable_pipes("ner")  # Disable the NER component of the original model

# Step 2: Load the training data from JSON
TRAINING_DATA = []
with open("project-7-at-2023-07-13-12-38-aa52cb06.json", "r") as f:
    json_data = json.load(f)

for data in json_data:
    text = data["text"]
    entities = data["label"]
    entity_tuples = []
    for entity in entities:
        start = entity["start"]
        end = entity["end"]
        label = str(entity["labels"][0])  # Convert label to string format
        entity_tuples.append((start, end, label))
    TRAINING_DATA.append((text, {"entities": entity_tuples}))    


# Step 3: Enable and train the NER component with rehearsal
nlp.enable_pipe("ner")


#Step 5: Training the model
n_iter = 30
for _ in range(n_iter):
    losses = {}
    random.shuffle(TRAINING_DATA)
    batches = minibatch(TRAINING_DATA, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        examples = []
        for text, annotation in zip(texts, annotations):
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, annotation)
            examples.append(example)

        nlp.update(examples, losses=losses)

    # Step 6: Generate additional examples using original model predictions as annotations (rehearsal)
    rehearsal_examples = []
    for text, _ in TRAINING_DATA:
        doc = nlp(text)
        rehearsal_entities = [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]
        rehearsal_examples.append(Example.from_dict(doc, {"entities": rehearsal_entities}))

    # Step 7: Combine the original and rehearsal examples
    combined_examples = examples + rehearsal_examples
    nlp.update(combined_examples, losses=losses)
    print("Losses:", losses)
# Out:
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 69.52981865239956}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 40.487405186913634}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 36.14376766816615}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 31.472512658421003}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 52.69568395905905}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 58.71613860207239}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 78.64948080326072}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 54.36086083917658}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 58.347731899247115}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 79.52791448633815}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 62.33102255340523}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 53.245793605236514}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 34.19674443898427}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 33.53524104046035}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 50.860320931293074}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 55.79785925433316}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 42.37474524763013}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 22.52965032140287}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 6.721757058042354}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 3.451614428309256}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 2.1306140426338276}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 2.204119445305018}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 1.8570108635721252}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 2.0104943919673017}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 3.01797551460703}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 2.1285915814684775}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 1.228729227410085}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 1.9785558863910215}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 2.0627574788387943}
# Losses: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'ner': 3.164072340001001}

# %%
# !pip install -U spacy
# !python3 -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.apple.com/simple/, https://artifacts.apple.com/api/pypi/apple-pypi-integration-local/simple/
# Collecting spacy
#   Downloading https://pypi.apple.com/packages/packages/b2/6d/7abebaa1df4d895dc5fad6eb26ce2b7f1e401d709c17cc3b8bff62248884/spacy-3.6.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 3.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy) (1.21.6)
# Requirement already satisfied, skipping upgrade: smart-open<7.0.0,>=5.2.1 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy) (6.3.0)
# Collecting srsly<3.0.0,>=2.4.3
#   Downlo
10-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 2.3 MB/s eta 0:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading https://pypi.apple.com/packages/packages/63/05/2d7acb83610e0c5171dfcb4a2968d676800da8082fc456e284fa8e0924f4/confection-0.1.0-py3-none-any.whl (34 kB)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=2.0 in /usr/local/miniconda/lib/python3.7/site-packages (from jinja2->spacy) (2.1.2)
# Requirement already satisfied, skipping upgrade: click<9.0.0,>=7.1.1 in /usr/local/miniconda/lib/python3.7/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied, skipping upgrade: zipp>=0.5; python_version < "3.8" in /usr/local/miniconda/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.11.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/miniconda/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.10.0,>=0.3.0->spacy) (4.11.3)
# Installing collected packages: catalogue, srsly, pydantic, wasabi, typer, pathy, cymem, murmurhash, preshed, blis, confection, thinc, spacy-loggers, langcodes, spacy-legacy, spacy
# Successfully installed blis-0.7.10 catalogue-2.0.8 confection-0.1.0 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.2 preshed-3.0.8 pydantic-1.10.11 spacy-3.6.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.7 thinc-8.1.10 typer-0.9.0 wasabi-1.1.2
# 2023-07-24 06:09:11.061229: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/teradata/client/16.20/lib64:/opt/vertica/lib64:
# 2023-07-24 06:09:11.061273: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-07-24 06:09:12.884880: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/teradata/client/16.20/lib64:/opt/vertica/lib64:
# 2023-07-24 06:09:12.884918: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-07-24 06:09:12.884950: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-18-144-196.us-west-2.compute.internal): /proc/driver/nvidia/version does not exist
# Looking in indexes: https://pypi.apple.com/simple/, https://artifacts.apple.com/api/pypi/apple-pypi-integration-local/simple/
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 7.3 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/miniconda/lib/python3.7/site-packages (from en-core-web-sm==3.6.0) (3.6.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.11)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (61.2.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.21.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.22.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: typing-extensions<4.5.0,>=3.7.4.1; python_version < "3.8" in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.4.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.63.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: jinja2 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/miniconda/lib/python3.7/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/miniconda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/miniconda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.25.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/miniconda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/miniconda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/miniconda/lib/python3.7/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/miniconda/lib/python3.7/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: zipp>=0.5; python_version < "3.8" in /usr/local/miniconda/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.11.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/miniconda/lib/python3.7/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/miniconda/lib/python3.7/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/miniconda/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.11.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
output_dir = "Custom_Ner/"  # Replace with the desired output directory
nlp.to_disk(output_dir)

# %%
# !pip install --upgrade pyOpenSSL
# Out:
# Looking in indexes: https://pypi.apple.com/simple/, https://artifacts.apple.com/api/pypi/apple-pypi-integration-local/simple/
# Collecting pyOpenSSL
#   Downloading https://pypi.apple.com/packages/packages/f0/e2/f8b4f1c67933a4907e52228241f4bd52169f3196b70af04403b29c63238a/pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 3.3 MB/s eta 0:00:011
# Requirement already satisfied, skipping upgrade: cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 in /usr/local/miniconda/lib/python3.7/site-packages (from pyOpenSSL) (41.0.2)
# Requirement already satisfied, skipping upgrade: cffi>=1.12 in /usr/local/miniconda/lib/python3.7/site-packages (from cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (1.15.0)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/miniconda/lib/python3.7/site-packages (from cffi>=1.12->cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (2.21)
# Installing collected packages: pyOpenSSL
#   Attempting uninstall: pyOpenSSL
#     Found existing installation: pyOpenSSL 20.0.1
#     Uninstalling pyOpenSSL-20.0.1:
#       Successfully uninstalled pyOpenSSL-20.0.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# snowflake-connector-python 2.7.1 requires cryptography<4.0.0,>=3.1.0, but you'll have cryptography 41.0.2 which is incompatible.
# snowflake-connector-python 2.7.1 requires pyOpenSSL<21.0.0,>=16.2.0, but you'll have pyopenssl 23.2.0 which is incompatible.
# gbiio 1.13.1 requires cryptography==3.4.8, but you'll have cryptography 41.0.2 which is incompatible.
# Successfully installed pyOpenSSL-23.2.0

# %%
# !pip install cryptography==3.4.8 pyOpenSSL==16.2.0
# Out:
# Looking in indexes: https://pypi.apple.com/simple/, https://artifacts.apple.com/api/pypi/apple-pypi-integration-local/simple/
# Collecting cryptography==3.4.8
#   Using cached https://pypi.apple.com/packages/packages/96/07/4d23f8e34e56d8eeb2c37cd5924928a01c3dd756a1d99e470181bc57551e/cryptography-3.4.8-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting pyOpenSSL==16.2.0
#   Downloading https://pypi.apple.com/packages/packages/ac/93/b4cd538d31adacd07f83013860db6b88d78755af1f3fefe68ec22d397e7b/pyOpenSSL-16.2.0-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 6.3 MB/s  eta 0:00:01
# Requirement already satisfied: cffi>=1.12 in /usr/local/miniconda/lib/python3.7/site-packages (from cryptography==3.4.8) (1.15.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/miniconda/lib/python3.7/site-packages (from pyOpenSSL==16.2.0) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/miniconda/lib/python3.7/site-packages (from cffi>=1.12->cryptography==3.4.8) (2.21)
# Installing collected packages: cryptography, pyOpenSSL
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 41.0.2
#     Uninstalling cryptography-41.0.2:
#       Successfully uninstalled cryptography-41.0.2
#   Attempting uninstall: pyOpenSSL
#     Found existing installation: pyOpenSSL 23.2.0
#     Uninstalling pyOpenSSL-23.2.0:
#       Successfully uninstalled pyOpenSSL-23.2.0
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# pdfminer-six 20221105 requires cryptography>=36.0.0, but you'll have cryptography 3.4.8 which is incompatible.
# gbiutils 1.8.12 requires cryptography==2.9.2, but you'll have cryptography 3.4.8 which is incompatible.
# gbiutils 1.8.12 requires pycryptodome==3.9, but you'll have pycryptodome 3.17 which is incompatible.
# gbiutils 1.8.12 requires recertifi==1.1.1, but you'll have recertifi 1.2.0 which is incompatible.
# gbiutils 1.8.12 requires six==1.15.0, but you'll have six 1.16.0 which is incompatible.
# Successfully installed cryptography-3.4.8 pyOpenSSL-16.2.0
